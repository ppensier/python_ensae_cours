# %%
# Installation Numpy
pip install numpy
# Out:
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (2.1.2)

# %%
import numpy as np

# %%
pip install pandas
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().system('pip install pandas')
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1428, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1470, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1277, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1905, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# File /opt/conda/lib/python3.12/site-packages/debugpy/_vendored/pydevd/pydevd.py:2197, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2194             from_this_thread.append(frame_custom_thread_id)
#    2196     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2197         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2199 frames_list = None
#    2201 if keep_suspended:
#    2202     # This means that we should pause again after a set next statement.
#
# File /opt/conda/lib/python3.12/site-packages/debugpy/_vendored/pydevd/pydevd.py:2266, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2263                 queue.put(internal_cmd)
#    2264                 wait_timeout = TIMEOUT_FAST
# -> 2266         notify_event.wait(wait_timeout)
#    2267         notify_event.clear()
#    2269 finally:
#
# File /opt/conda/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /opt/conda/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
import pandas as pd
url = "https://www.insee.fr/fr/statistiques/fichier/6800675/v_commune_2023.csv"
df = pd.read_csv(url)
df.head()
# Out:
#   TYPECOM    COM   REG DEP CTCD  ARR  TNCC                    NCC  \
# 0     COM  01001  84.0  01  01D  012     5  ABERGEMENT CLEMENCIAT
# 1     COM  01002  84.0  01  01D  011     5    ABERGEMENT DE VAREY
# 2     COM  01004  84.0  01  01D  011     1      AMBERIEU EN BUGEY
# 3     COM  01005  84.0  01  01D  012     1    AMBERIEUX EN DOMBES
# 4     COM  01006  84.0  01  01D  011     1                AMBLEON
#
#                   NCCENR                  LIBELLE   CAN  COMPARENT
# 0  Abergement-Clémenciat  L'Abergement-Clémenciat  0108        NaN
# 1    Abergement-de-Varey    L'Abergement-de-Varey  0101        NaN
# 2      Ambérieu-en-Bugey        Ambérieu-en-Bugey  0101        NaN
# 3    Ambérieux-en-Dombes      Ambérieux-en-Dombes  0122        NaN
# 4                Ambléon                  Ambléon  0104        NaN

# %%
df.loc[df['COMPARENT'].isna(), ['COM', 'REG']]
# Out:
#          COM   REG
# 0      01001  84.0
# 1      01002  84.0
# 2      01004  84.0
# 3      01005  84.0
# 4      01006  84.0
# ...      ...   ...
# 37558  97613   6.0
# 37559  97614   6.0
# 37560  97615   6.0
# 37561  97616   6.0
# 37562  97617   6.0
#
# [34945 rows x 2 columns]
